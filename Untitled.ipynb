# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
pieces=[]
for year in range(1880,2022):
    path=f"dataset/babynames/yob{year}.txt"
    data=pd.read_csv(path,names=["name","sex","births"]) 
    data["year"]=year
    pieces.append(data)
names=pd.concat(pieces,ignore_index=True)

# %%
names
# Out:
#               name sex  births  year
# 0             Mary   F    7065  1880
# 1             Anna   F    2604  1880
# 2             Emma   F    2003  1880
# 3        Elizabeth   F    1939  1880
# 4           Minnie   F    1746  1880
# ...            ...  ..     ...   ...
# 2051164     Zyeire   M       5  2021
# 2051165       Zyel   M       5  2021
# 2051166      Zyian   M       5  2021
# 2051167      Zylar   M       5  2021
# 2051168        Zyn   M       5  2021
#
# [2051169 rows x 4 columns]

# %%
total_birth=names.pivot_table(values="births",index="year",columns="sex",aggfunc=sum)
# Out:
# C:\Users\BlueKing\AppData\Local\Temp\ipykernel_6616\701626032.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   total_birth=names.pivot_table(values="births",index="year",columns="sex",aggfunc=sum)

# %%
total_birth.plot(title="Total births by sex and year")
# Out:
# <Axes: title={'center': 'Total births by sex and year'}, xlabel='year'>

# %%
names = names.groupby(['year', 'sex']).apply(
    lambda group: group.assign(proportion=group['births'] / group['births'].sum())
).reset_index(drop=True)

# %%
names
# Out:
#               name sex  births  year  proportion
# 0             Mary   F    7065  1880    0.077643
# 1             Anna   F    2604  1880    0.028618
# 2             Emma   F    2003  1880    0.022013
# 3        Elizabeth   F    1939  1880    0.021309
# 4           Minnie   F    1746  1880    0.019188
# ...            ...  ..     ...   ...         ...
# 2051164     Zyeire   M       5  2021    0.000003
# 2051165       Zyel   M       5  2021    0.000003
# 2051166      Zyian   M       5  2021    0.000003
# 2051167      Zylar   M       5  2021    0.000003
# 2051168        Zyn   M       5  2021    0.000003
#
# [2051169 rows x 5 columns]

# %%
names.groupby(["year","sex"])["proportion"].sum() # the proportions add up to 1, 
                                                  # indicating the proportions were calculated correctly
# Out:
# year  sex
# 1880  F      1.0
#       M      1.0
# 1881  F      1.0
#       M      1.0
# 1882  F      1.0
#             ...
# 2019  M      1.0
# 2020  F      1.0
#       M      1.0
# 2021  F      1.0
#       M      1.0
# Name: proportion, Length: 284, dtype: float64

# %%
grouped = names.groupby(['year', 'sex'])
Top1000_name = grouped.apply(
    lambda group: group.sort_values("births", ascending=False).head(1000)
).reset_index(drop=True)

# %%
Top1000_name=Top1000_name.reset_index(drop=True)

# %%
Top1000_name.head()
# Out:
#         name sex  births  year  proportion
# 0       Mary   F    7065  1880    0.077643
# 1       Anna   F    2604  1880    0.028618
# 2       Emma   F    2003  1880    0.022013
# 3  Elizabeth   F    1939  1880    0.021309
# 4     Minnie   F    1746  1880    0.019188

# %%
boys=Top1000_name[Top1000_name["sex"]=="M"] 
girls=Top1000_name[Top1000_name["sex"]=="F"]

# %%
boys
# Out:
#            name sex  births  year  proportion
# 942        John   M    9655  1880    0.087381
# 943     William   M    9533  1880    0.086277
# 944       James   M    5927  1880    0.053641
# 945     Charles   M    5348  1880    0.048401
# 946      George   M    5126  1880    0.046392
# ...         ...  ..     ...   ...         ...
# 283872      Zev   M     218  2021    0.000126
# 283873   Harris   M     217  2021    0.000125
# 283874   Ronnie   M     217  2021    0.000125
# 283875  Merrick   M     217  2021    0.000125
# 283876   Mayson   M     217  2021    0.000125
#
# [141997 rows x 5 columns]

# %%
girls
# Out:
#              name sex  births  year  proportion
# 0            Mary   F    7065  1880    0.077643
# 1            Anna   F    2604  1880    0.028618
# 2            Emma   F    2003  1880    0.022013
# 3       Elizabeth   F    1939  1880    0.021309
# 4          Minnie   F    1746  1880    0.019188
# ...           ...  ..     ...   ...         ...
# 282872     Soleil   F     255  2021    0.000157
# 282873     Sandra   F     255  2021    0.000157
# 282874   Eleanora   F     255  2021    0.000157
# 282875      Aarya   F     255  2021    0.000157
# 282876  Annabella   F     254  2021    0.000156
#
# [141880 rows x 5 columns]

# %%
total_birth=Top1000_name.pivot_table(values="births",index="year",columns="name",aggfunc=sum)
subset = total_birth.loc[:, ["John", "Harry", "Mary", "Marilyn"]]
axes=subset.plot(subplots=True, figsize=(12, 10), title="Number of births per year")

for ax in axes:
    ax.set_ylabel("Number of Births")
    ax.grid(axis="y",linestyle="--",alpha=0.7)

plt.show()
# Out:
# C:\Users\BlueKing\AppData\Local\Temp\ipykernel_6616\2374537405.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   total_birth=Top1000_name.pivot_table(values="births",index="year",columns="name",aggfunc=sum)

# %%
john_data = boys[boys["name"] == "John"]["births"].sum()

# %%
john_data
# Out:
# 5147751

# %%
total_birth[["Mary"]].sum()
# Out:
# name
# Mary    4144777.0
# dtype: float64

# %%
#increase in name in diversity

# %%
table=Top1000_name.pivot_table(values="proportion",index="year",columns="name",aggfunc=sum)
# Out:
# C:\Users\BlueKing\AppData\Local\Temp\ipykernel_6616\219039980.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table=Top1000_name.pivot_table(values="proportion",index="year",columns="name",aggfunc=sum)

# %%
df=boys[boys["year"]==2020]

# %%
df
# Out:
#            name sex  births  year  proportion
# 280877     Liam   M   19777  2020    0.011510
# 280878     Noah   M   18364  2020    0.010688
# 280879   Oliver   M   14234  2020    0.008284
# 280880   Elijah   M   13136  2020    0.007645
# 280881  William   M   12613  2020    0.007341
# ...         ...  ..     ...   ...         ...
# 281872  Jericho   M     213  2020    0.000124
# 281873   Harris   M     213  2020    0.000124
# 281874  Rogelio   M     212  2020    0.000123
# 281875   Jerome   M     211  2020    0.000123
# 281876    Karim   M     211  2020    0.000123
#
# [1000 rows x 5 columns]

# %%
proportion_cumsum=df["proportion"].sort_values(ascending=False).cumsum()

# %%
proportion_cumsum[:10]
# Out:
# 280877    0.011510
# 280878    0.022198
# 280879    0.030482
# 280880    0.038127
# 280881    0.045467
# 280882    0.052651
# 280883    0.059756
# 280884    0.066358
# 280885    0.072623
# 280886    0.078574
# Name: proportion, dtype: float64

# %%
proportion_cumsum.searchsorted(0.5)
# Out:
# 162

# %%
df=boys[boys.year==1900]
in1900=df.sort_values("proportion",ascending=False).proportion.cumsum()
in1900.searchsorted(0.5)+1
# Out:
# 25

# %%
# calculates the number of top names (sorted by proportion) needed to reach at least 50%
diversity = (Top1000_name.sort_values(by="proportion", ascending=False)
                     .groupby(["year", "sex"])["proportion"]
                     .apply(lambda x: x.cumsum().searchsorted(0.5) + 1)
                     .unstack())

# %%
diversity.head()
# Out:
# sex    F   M
# year
# 1880  38  14
# 1881  38  14
# 1882  38  15
# 1883  39  15
# 1884  39  16

# %%
diversity.plot(title="Number of population name in 50%")
# Out:
# <Axes: title={'center': 'Number of population name in 50%'}, xlabel='year'>

# %%
names["last_letter"] = names["name"].map(lambda lastletter: lastletter[-1])
table = names.pivot_table(values="births", index="last_letter", columns=["sex", "year"], aggfunc="sum")

# %%
table
# Out:
# sex                F                                                        \
# year            1880     1881     1882     1883     1884     1885     1886
# last_letter
# a            31446.0  31581.0  36536.0  38330.0  43680.0  45408.0  49100.0
# b                NaN      NaN      NaN      NaN      NaN      NaN      NaN
# c                NaN      NaN      5.0      5.0      NaN      NaN      NaN
# d              609.0    607.0    734.0    810.0    916.0    862.0   1007.0
# e            33378.0  34080.0  40399.0  41914.0  48089.0  49616.0  53884.0
# f                NaN      NaN      NaN      NaN      NaN      NaN      NaN
# g                7.0      5.0     12.0      8.0     24.0     11.0     18.0
# h             4863.0   4784.0   5567.0   5701.0   6602.0   6624.0   7146.0
# i               61.0     78.0     81.0     76.0     84.0     92.0     85.0
# j                NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...

# %%
subtable=table.reindex(columns=[2000,2010,2020], level="year")
subtable.head()
# Out:
# sex                 F                             M
# year             2000      2010      2020      2000      2010      2020
# last_letter
# a            675485.0  670605.0  614720.0   40837.0   28438.0   33800.0
# b               372.0     450.0     530.0   50892.0   38859.0   18067.0
# c               525.0     946.0     892.0   26998.0   23125.0   16652.0
# d              4380.0    2607.0    3810.0   64251.0   44398.0   38875.0
# e            318199.0  313833.0  285170.0  148821.0  129012.0  116438.0

# %%
subtable.sum()
# Out:
# sex  year
# F    2000    1813960.0
#      2010    1759010.0
#      2020    1609171.0
# M    2000    1961702.0
#      2010    1898382.0
#      2020    1718248.0
# dtype: float64

# %%
letter_prop=subtable/subtable.sum() #helps analyze and compare last letter of name

# %%
letter_prop
# Out:
# sex                 F                             M
# year             2000      2010      2020      2000      2010      2020
# last_letter
# a            0.372381  0.381240  0.382010  0.020817  0.014980  0.019671
# b            0.000205  0.000256  0.000329  0.025943  0.020470  0.010515
# c            0.000289  0.000538  0.000554  0.013763  0.012181  0.009691
# d            0.002415  0.001482  0.002368  0.032753  0.023387  0.022625
# e            0.175417  0.178415  0.177215  0.075863  0.067959  0.067766
# f            0.000015  0.000055  0.000100  0.000874  0.001188  0.001584
# g            0.000322  0.000374  0.000441  0.001223  0.001404  0.002668
# h            0.064617  0.075852  0.069228  0.043346  0.051670  0.054557
# i            0.023460  0.031734  0.047694  0.009339  0.022628  0.032479
# j            0.000054  0.000090  0.000088  0.000468  0.000769  0.000850
# k            0.000319  0.000356  0.000360  0.022692  0.018541  0.020387
# ...

# %%
fig, axes = plt.subplots(2, 1, figsize=(10, 8))  # Use plt.subplots for creating subplots

# Plotting for males
letter_prop["M"].plot(kind="bar", rot=0, ax=axes[0], title="Male")

# Plotting for females
letter_prop["F"].plot(kind="bar", rot=0, ax=axes[1], title="Female",legend=False)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
# Filter the DataFrame to include only names ending with "e"
names_ending_with_e = girls[girls["name"].str.endswith("e")]
names_ending_with_e
# Out:
#             name sex  births  year  proportion
# 4         Minnie   F    1746  1880    0.019188
# 7          Alice   F    1414  1880    0.015540
# 10         Annie   F    1258  1880    0.013825
# 13      Florence   F    1063  1880    0.011682
# 17        Nellie   F     995  1880    0.010935
# ...          ...  ..     ...   ...         ...
# 282841   Braylee   F     267  2021    0.000164
# 282850   Jaylene   F     264  2021    0.000162
# 282858    Jaylee   F     263  2021    0.000162
# 282864      Zoie   F     261  2021    0.000160
# 282865   Arlette   F     259  2021    0.000159
#
# [41423 rows x 5 columns]

# %%
names_ending_with_a = girls[girls["name"].str.endswith("a")]
names_ending_with_a
# Out:
#              name sex  births  year  proportion
# 1            Anna   F    2604  1880    0.028618
# 2            Emma   F    2003  1880    0.022013
# 6             Ida   F    1472  1880    0.016177
# 8          Bertha   F    1320  1880    0.014507
# 11          Clara   F    1226  1880    0.013474
# ...           ...  ..     ...   ...         ...
# 282870    Tatiana   F     256  2021    0.000157
# 282873     Sandra   F     255  2021    0.000157
# 282874   Eleanora   F     255  2021    0.000157
# 282875      Aarya   F     255  2021    0.000157
# 282876  Annabella   F     254  2021    0.000156
#
# [54304 rows x 5 columns]

# %%
letter_prop=table/table.sum()

# %%
letter_prop
# Out:
# sex                 F                                                    \
# year             1880      1881      1882      1883      1884      1885
# last_letter
# a            0.345587  0.343440  0.338764  0.341251  0.338550  0.341270
# b                 NaN       NaN       NaN       NaN       NaN       NaN
# c                 NaN       NaN  0.000046  0.000045       NaN       NaN
# d            0.006693  0.006601  0.006806  0.007211  0.007100  0.006478
# e            0.366819  0.370616  0.374582  0.373159  0.372722  0.372896
# f                 NaN       NaN       NaN       NaN       NaN       NaN
# g            0.000077  0.000054  0.000111  0.000071  0.000186  0.000083
# h            0.053444  0.052025  0.051618  0.050756  0.051170  0.049784
# i            0.000670  0.000848  0.000751  0.000677  0.000651  0.000691
# j                 NaN       NaN       NaN       NaN       NaN       NaN
# k            0.000143  0.000163  0.000102  0.000151  0.000163  0.000135
# ...

# %%
dny_ts=letter_prop.loc[["d","n","y"],"M"].T

# %%
dny_ts.head()
# Out:
# last_letter         d         n         y
# year
# 1880         0.083055  0.153213  0.075760
# 1881         0.083247  0.153214  0.077451
# 1882         0.085340  0.149560  0.077537
# 1883         0.084066  0.151646  0.079144
# 1884         0.086120  0.149915  0.080405

# %%
dny_ts.plot()
# Out:
# <Axes: xlabel='year'>

# %%
all_names=pd.Series(Top1000_name["name"].unique())

# %%
lesl_like=all_names[all_names.str.contains("Lesl")]

# %%
lesl_like
# Out:
# 632     Leslie
# 2294    Lesley
# 4262    Leslee
# 4728     Lesli
# 6103     Lesly
# dtype: object

# %%
filtered=Top1000_name[Top1000_name["name"].isin(lesl_like)]

# %%
filtered.groupby("name")["births"].sum()
# Out:
# name
# Leslee      1082
# Lesley     35022
# Lesli        929
# Leslie    379569
# Lesly      11428
# Name: births, dtype: int64

# %%
table=filtered.pivot_table(values="births",index="year",columns="sex",aggfunc=sum)
table=table.div(table.sum(axis="columns"),axis="index")
table.tail()
# Out:
# C:\Users\BlueKing\AppData\Local\Temp\ipykernel_6616\864187817.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table=filtered.pivot_table(values="births",index="year",columns="sex",aggfunc=sum)
# sex     F   M
# year
# 2017  1.0 NaN
# 2018  1.0 NaN
# 2019  1.0 NaN
# 2020  1.0 NaN
# 2021  1.0 NaN

# %%
table.plot(style={"M": "k-", "F": "k--"})
plt.show()
